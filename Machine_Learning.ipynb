# %%
# The python kernel does not appear to be a conda environment.
# Conda commands like 'conda create' are not supported in Colab.
# To install packages, please use '!pip install <package_name>' instead.
# If you need a specific Python version, you might need to look into
# alternative Colab runtimes or more advanced environment setup,
# as creating new isolated Conda environments is not directly supported here.
# Original command: conda create -n python_ml python==3.10 -y

# %%
pip install conda python_ml python==3.5.0
# Out:
# ERROR: Ignored the following yanked versions: 3.0.6, 3.5.0, 3.7.0, 3.17.0, 4.0.0, 4.0.1, 4.0.2, 4.0.3, 4.0.4, 4.0.5, 4.0.7, 4.0.8, 4.0.9, 4.1.2, 4.1.6, 4.2.6, 4.2.7, 4.3.13, 4.3.16
# ERROR: Could not find a version that satisfies the requirement conda (from versions: none)
# ERROR: No matching distribution found for conda

# %%
pip install scikit-learn

# %%
pip install pandas matplotlib seaborn ipykernel openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# #  Basics of Scikit learn

# %%
# importing lib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # supervised learning -- simple linear regreeson

# %%
from sklearn.linear_model import LinearRegression

# %%
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
X= df[['total_bill']]
y= df[['tip']]

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
#predict
model.predict([[50]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[6.17149548]])

# %%
#one go
import pandas as pd
from sklearn.linear_model import LinearRegression

df=sns.load_dataset('tips')

X= df[['total_bill']]
y = df[['tip']]

model = LinearRegression()
model.fit(X,y)
model.predict([[34.55]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[4.54886669]])

# %% [markdown]
# # intermediate level of scikit learn

# %%
# simple linear regression
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression

df=sns.load_dataset('tips')

X= df[['total_bill']]
y = df[['tip']]

model = LinearRegression()
model.fit(X,y)
model.predict([[34.55]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[4.54886669]])

# %%
sns.lmplot(x='total_bill',y='tip',data=df)

# %%
#multi linear regression
import pandas as pd
from sklearn.linear_model import LinearRegression

df=sns.load_dataset('tips')

X= df[['total_bill','size']]
y = df[['tip']]

model = LinearRegression()
model.fit(X,y)
model.predict([[34.45, 2]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[4.24811478]])

# %%
#multi linear regression
import pandas as pd
from sklearn.linear_model import LinearRegression

df=sns.load_dataset('tips')
df.head()
#encode smoker column
# df['smoker'] = df['smoker'].map({'Yes': 1, 'No': 0})
df['smoker_num'] = df['smoker'].map({'Yes' : 1 , 'No' : 0 })
df.head()
X = df[['total_bill','size','smoker_num']]
y = df[['tip']]
model = LinearRegression()
model.fit(X,y)
print(model.predict([[35.527,5,1]]))
print(model.predict([[35.527,5,0]]))
# Out:
# [[4.8628136]]
# [[4.94624615]]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Classification

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# # Binary classification

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

df=sns.load_dataset('tips')
df.head()

df.head()
X = df[['total_bill','size','tip']]
y = df[['smoker']]
model = LogisticRegression()
model.fit(X,y)
model.predict([[50.527,2,5.67]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype=object)

# %%
import pandas as pd
from sklearn.naive_bayes import  GaussianNB as GNB

df=sns.load_dataset('tips')
df.head()

df.head()
X = df[['total_bill','size','tip']]
y = df[['smoker']]
model = GNB()
model.fit(X,y)
model.predict([[50.527,2,5.67]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype='<U3')

# %%
# Decision tree
import pandas as pd

from sklearn.tree import DecisionTreeClassifier

df=sns.load_dataset('tips')
df.head()

df.head()
X = df[['total_bill','size','tip']]
y = df[['smoker']]
model = DecisionTreeClassifier()
model.fit(X,y)
model.predict([[50.527,2,5.67]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype=object)

# %%
# decision tree regressor
import pandas as pd

from sklearn.tree import DecisionTreeClassifier , DecisionTreeRegressor

df=sns.load_dataset('tips')
df.head()

df.head()
X = df[['total_bill','size']]
y = df[['tip']]
model = DecisionTreeRegressor()
model.fit(X,y)
model.predict([[50.527,2]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([10.])

# %% [markdown]
# #  Metrics

# %% [markdown]
# #  Regression Metrics

# %%
import pandas as pd
import numpy as np

import seaborn as sns
from sklearn.linear_model import LinearRegression
#load data set
df = sns.load_dataset('tips')
df.head()

X= df[['total_bill', 'size']]
y= df[['tip']]

#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.8)

#call the model
model= LinearRegression()
#fit the model
model.fit(X_train , y_train)
#metric to evaluate the model
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error , mean_absolute_percentage_error
y_prediction = model.predict(X_test)
print(f"mean squared error {mean_squared_error(y_test,y_prediction)}")
print(f"r2 score {r2_score(y_test,y_prediction)}")
print(f"mean absolute error {mean_absolute_error(y_test,y_prediction)}")
#root mean squared error
print(f"root mean squared error {np.sqrt(mean_squared_error(y_test,y_prediction))}")
print(f"mean absolute percentage error {mean_absolute_percentage_error(y_test,y_prediction)}")
# #predict
# model.predict(X_test)
# Out:
# mean squared error 0.7308247389500745
# r2 score 0.5561025044306949
# mean absolute error 0.6853127620612965
# root mean squared error 0.8548828802532394
# mean absolute percentage error 0.26336141184116363

# %% [markdown]
# #  ML Models bulding or development
# #-- define the problem
# # --  data  collection/ data gathering
# #--  Data preprocessing--cleaning the data so ml model can predict correctly (EDA + Data Wrangling)
# # --  Choose a model
# # -- Spliting the data
#        --- X -- independent(can be 2 or more) (predict y)--predictors--features--input
#        ___ y -- dependent--label--output
# #-- Evaluating the Model
#     -- based on traing-testing
# #-- Hyper parameter tunning
#     __ start performing goodly
#
# #-- Training & Testing
# #-- Model Finalization
#   --- check on multiple data
# #--- Deploy the Model
# #-- Retest , update , version , monitor
